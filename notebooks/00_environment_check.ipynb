# %% [markdown]
# # Environment Check
# Validate Python, settings, imports, and local service assumptions.

# %%
import sys
from src.config.settings import load_settings
settings = load_settings(env_file='../.env')
print(sys.version)
print(settings.model_dump(exclude={'questdb_password'}))
