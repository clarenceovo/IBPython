# %% [markdown]
# # Load OHLCV
# Loads IBKR historical bars and displays a DataFrame.

# %%
import pandas as pd
from mpmath import rand

from src.config.settings import load_settings
from src.feeds.ibkr_feed import IBKRFeedClient
from src.feeds.models import OHLCVRequest
from random import randint
settings = load_settings(env_file='../.env')
request = OHLCVRequest(symbol='SPY', asset_class='equity', exchange='SMART', currency='USD', duration='1 D', bar_size='1 min')
client = IBKRFeedClient(settings.ibkr_host, settings.ibkr_port, randint(0,99))
try:
    await client.connect()
    bars = await client.load_historical_ohlcv(request)
    display(pd.DataFrame([bar.model_dump() for bar in bars]).tail())
finally:
    await client.disconnect()
# Out:
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2107]: HMDS data farm connection is inactive but should be available upon demand.apachmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
#     symbol asset_class exchange currency                 timestamp    open  \
# 178    SPY      equity    SMART      USD 2026-05-14 16:28:00+00:00  748.32
# 179    SPY      equity    SMART      USD 2026-05-14 16:29:00+00:00  748.09
# 180    SPY      equity    SMART      USD 2026-05-14 16:30:00+00:00  748.01
# 181    SPY      equity    SMART      USD 2026-05-14 16:31:00+00:00  748.23
# 182    SPY      equity    SMART      USD 2026-05-14 16:32:00+00:00  748.17
#
#        high     low   close   volume bar_size source  \
# 178  748.32  748.09  748.15  15810.0    1 min   ibkr
# 179  748.09  747.86  748.00  40300.0    1 min   ibkr
# 180  748.21  747.92  748.21  23847.0    1 min   ibkr
# 181  748.26  748.09  748.11  11865.0    1 min   ibkr
# 182  748.18  747.99  747.99  18874.0    1 min   ibkr
#
#                                         metadata
# 178  {'what_to_show': 'TRADES', 'use_rth': True}
# 179  {'what_to_show': 'TRADES', 'use_rth': True}
# 180  {'what_to_show': 'TRADES', 'use_rth': True}
# 181  {'what_to_show': 'TRADES', 'use_rth': True}
# 182  {'what_to_show': 'TRADES', 'use_rth': True}
# IBKR disconnected – attempting reconnection
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2107]: HMDS data farm connection is inactive but should be available upon demand.apachmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR connection timeout
