# %% [markdown]
# # Load OHLCV
# Loads IBKR historical bars and displays a DataFrame.

# %%
import pandas as pd
from mpmath import rand

from src.config.settings import load_settings
from src.feeds.ibkr_feed import IBKRFeedClient
from src.feeds.models import OHLCVRequest
from random import randint
settings = load_settings(env_file='../.env')
request = OHLCVRequest(symbol='SPY', asset_class='equity', exchange='SMART', currency='USD', duration='1 D', bar_size='1 min')
client = IBKRFeedClient(settings.ibkr_host, settings.ibkr_port, randint(0,99))
try:
    await client.connect()
    bars = await client.load_historical_ohlcv(request)
    display(pd.DataFrame([bar.model_dump() for bar in bars]).tail())
finally:
    await client.disconnect()
# Out:
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
#     symbol asset_class exchange currency                 timestamp    open  \
# 151    SPY      equity    SMART      USD 2026-05-15 16:01:00+00:00  740.38
# 152    SPY      equity    SMART      USD 2026-05-15 16:02:00+00:00  740.50
# 153    SPY      equity    SMART      USD 2026-05-15 16:03:00+00:00  740.59
# 154    SPY      equity    SMART      USD 2026-05-15 16:04:00+00:00  740.12
# 155    SPY      equity    SMART      USD 2026-05-15 16:05:00+00:00  739.95
#
#        high     low   close   volume bar_size source  \
# 151  740.51  740.28  740.50  24781.0    1 min   ibkr
# 152  740.57  740.41  740.56  28667.0    1 min   ibkr
# 153  740.64  740.05  740.11  72105.0    1 min   ibkr
# 154  740.19  739.84  740.03  28484.0    1 min   ibkr
# 155  739.97  739.79  739.96   8173.0    1 min   ibkr
#
#                                         metadata
# 151  {'what_to_show': 'TRADES', 'use_rth': True}
# 152  {'what_to_show': 'TRADES', 'use_rth': True}
# 153  {'what_to_show': 'TRADES', 'use_rth': True}
# 154  {'what_to_show': 'TRADES', 'use_rth': True}
# 155  {'what_to_show': 'TRADES', 'use_rth': True}
# IBKR disconnected – attempting reconnection
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR connection timeout
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: apachmds; cashhmds; ushmds. The following farms are not connected: hfarm; secdefhk.
# IBKR connectivity event [1102]: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: apachmds; cashhmds; ushmds. The following farms are not connected: hfarm; secdefhk. (reqId=-1)
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashhmds; ushmds. The following farms are not connected: apachmds; secdefhk.
# IBKR connectivity event [1102]: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashhmds; ushmds. The following farms are not connected: apachmds; secdefhk. (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; apachmds; cashhmds; ushmds; secdefhk.
# IBKR connectivity event [1102]: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; apachmds; cashhmds; ushmds; secdefhk. (reqId=-1)
# Error 322, reqId 5: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first
# IBKR unhandled error [322]: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first (reqId=5)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# IBKR unhandled error [2158]: Sec-def data farm connection is OK:secdefhk (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:apachmds (reqId=-1)
# IBKR unhandled error [2104]: Market data farm connection is OK:hfarm (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:ushmds (reqId=-1)
# IBKR unhandled error [2106]: HMDS data farm connection is OK:cashhmds (reqId=-1)
# Error 322, reqId 5: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first
# IBKR unhandled error [322]: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first (reqId=5)
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; apachmds; cashhmds; ushmds; secdefhk.
# IBKR connectivity event [1102]: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; apachmds; cashhmds; ushmds; secdefhk. (reqId=-1)
# Error 322, reqId 6: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first
# IBKR unhandled error [322]: Error processing request.-'bX' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first (reqId=6)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# IBKR unhandled error [2103]: Market data farm connection is broken:hfarm (reqId=-1)
# IBKR unhandled error [2157]: Sec-def data farm connection is broken:secdefhk (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:apachmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:cashhmds (reqId=-1)
# IBKR unhandled error [2105]: HMDS data farm connection is broken:ushmds (reqId=-1)
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# IBKR connectivity event [1100]: Connectivity between IBKR and Trader Workstation has been lost. (reqId=-1)
# Peer closed connection.
# IBKR disconnected – attempting reconnection
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect attempt 1 failed: IBKR operation failed after retries: reconnect; next retry in 2s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect attempt 2 failed: IBKR operation failed after retries: reconnect; next retry in 4s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect attempt 3 failed: IBKR operation failed after retries: reconnect; next retry in 8s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect attempt 4 failed: IBKR operation failed after retries: reconnect; next retry in 16s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR reconnect attempt 5 failed: IBKR operation failed after retries: reconnect; next retry in 32s
# IBKR reconnection failed after 5 attempts
