# %% [markdown]
# # IBKR Connection Test
# Start TWS or IB Gateway before running this notebook.

# %%
from src.config.settings import load_settings
from src.feeds.ibkr_feed import IBKRFeedClient

settings = load_settings(env_file='../.env')
client = IBKRFeedClient(settings.ibkr_host, settings.ibkr_port, 99)
try:
    await client.connect()
    print('Connected to IBKR')
finally:
    await client.disconnect()
# Out:
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('100.90.57.25', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR connect failed on attempt 1/3; retrying in 0.50s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('100.90.57.25', 4001)")
# Make sure API port on TWS/IBG is open
# IBKR connect failed on attempt 2/3; retrying in 1.00s
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('100.90.57.25', 4001)")
# Make sure API port on TWS/IBG is open
# failed to connect to IBKR at 100.90.57.25:4001 clientId=99; last_ibkr_error=None
# Traceback (most recent call last):
#   File "/Users/hoclarence/PycharmProjects/IBPython/src/feeds/ibkr_connection.py", line 443, in with_retry
#     result = await call()
#              ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ib_insync/ib.py", line 1748, in connectAsync
#     await self.client.connectAsync(host, port, clientId, timeout)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ib_insync/client.py", line 211, in connectAsync
#     await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#   File "/opt/anaconda3/lib/python3.13/asyncio/tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ib_insync/connection.py", line 39, in connectAsync
#     self.transport, _ = await loop.create_connection(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         lambda: self, host, port)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/asyncio/base_events.py", line 1171, in create_connection
#     raise exceptions[0]
#   File "/opt/anaconda3/lib/python3.13/asyncio/base_events.py", line 1146, in create_connection
#     sock = await self._connect_sock(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#         exceptions, addrinfo, laddr_infos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/asyncio/base_events.py", line 1045, in _connect_sock
#     await self.sock_connect(sock, address)
#   File "/opt/anaconda3/lib/python3.13/asyncio/selector_events.py", line 641, in sock_connect
#     return await fut
#            ^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/asyncio/futures.py", line 286, in __await__
#     yield self  # This tells Task to wait for completion.
#     ^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/asyncio/futures.py", line 199, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/opt/anaconda3/lib/python3.13/asyncio/selector_events.py", line 681, in _sock_connect_cb
#     raise OSError(err, f'Connect call failed {address}')
# ConnectionRefusedError: [Errno 61] Connect call failed ('100.90.57.25', 4001)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/hoclarence/PycharmProjects/IBPython/src/feeds/ibkr_connection.py", line 224, in connect
#     await self._with_retry(
#     ...<2 lines>...
#     )
#   File "/Users/hoclarence/PycharmProjects/IBPython/src/feeds/ibkr_connection.py", line 462, in _with_retry
#     return await self.with_retry(call, operation=operation)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hoclarence/PycharmProjects/IBPython/src/feeds/ibkr_connection.py", line 458, in with_retry
#     raise RuntimeError(f"IBKR operation failed after retries: {operation}") from last_error
# RuntimeError: IBKR operation failed after retries: connect
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/PycharmProjects/IBPython/src/feeds/ibkr_connection.py:443, in IBKRConnectionManager.with_retry(self, call, operation)
#     442 await self.wait_for_ibkr_request(operation=operation)
# --> 443 result = await call()
#     444 elapsed = monotonic_time.monotonic() - t0
#
# File /opt/anaconda3/lib/python3.13/site-packages/ib_insync/ib.py:1748, in IB.connectAsync(self, host, port, clientId, timeout, readonly, account)
#    1746 try:
#    1747     # establish API connection
# -> 1748     await self.client.connectAsync(host, port, clientId, timeout)
#    1750     # autobind manual orders
#
# File /opt/anaconda3/lib/python3.13/site-packages/ib_insync/client.py:211, in Client.connectAsync(self, host, port, clientId, timeout)
#     210 timeout = timeout or None
# --> 211 await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#     212 self._logger.info('Connected')
#
# File /opt/anaconda3/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File /opt/anaconda3/lib/python3.13/site-packages/ib_insync/connection.py:39, in Connection.connectAsync(self, host, port)
#      38 loop = getLoop()
# ---> 39 self.transport, _ = await loop.create_connection(
#      40     lambda: self, host, port)
#
# File /opt/anaconda3/lib/python3.13/asyncio/base_events.py:1171, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1170 if len(exceptions) == 1:
# -> 1171     raise exceptions[0]
#    1172 elif exceptions:
#    1173     # If they all have the same str(), raise one.
#
# File /opt/anaconda3/lib/python3.13/asyncio/base_events.py:1146, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1145 try:
# -> 1146     sock = await self._connect_sock(
#    1147         exceptions, addrinfo, laddr_infos)
#    1148     break
#
# File /opt/anaconda3/lib/python3.13/asyncio/base_events.py:1045, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#    1044             raise OSError(f"no matching local address with {family=} found")
# -> 1045 await self.sock_connect(sock, address)
#    1046 return sock
#
# File /opt/anaconda3/lib/python3.13/asyncio/selector_events.py:641, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     640 try:
# --> 641     return await fut
#     642 finally:
#     643     # Needed to break cycles when an exception occurs.
#
# File /opt/anaconda3/lib/python3.13/asyncio/futures.py:286, in Future.__await__(self)
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#
# File /opt/anaconda3/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/lib/python3.13/asyncio/selector_events.py:681, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     679     if err != 0:
#     680         # Jump to any except clause below.
# --> 681         raise OSError(err, f'Connect call failed {address}')
#     682 except (BlockingIOError, InterruptedError):
#     683     # socket is still registered, the callback will be retried later
#
# ConnectionRefusedError: [Errno 61] Connect call failed ('100.90.57.25', 4001)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 7
#       5 client = IBKRFeedClient(settings.ibkr_host, settings.ibkr_port, 99)
#       6 try:
# ----> 7     await client.connect()
#       8     print('Connected to IBKR')
#       9 finally:
#
# File ~/PycharmProjects/IBPython/src/feeds/ibkr_feed.py:286, in IBKRFeedClient.connect(self)
#     285 async def connect(self) -> None:
# --> 286     await self._connection.connect()
#
# File ~/PycharmProjects/IBPython/src/feeds/ibkr_connection.py:224, in IBKRConnectionManager.connect(self)
#     222 t0 = monotonic_time.monotonic()
#     223 try:
# --> 224     await self._with_retry(
#     225         lambda: self._ib.connectAsync(self.host, self.port, clientId=self.client_id),
#     226         operation="connect",
#     227     )
#     228     if not self._ib.isConnected():
#     229         raise IBKRConnectionError("connectAsync returned but IBKR client is not connected")
#
# File ~/PycharmProjects/IBPython/src/feeds/ibkr_connection.py:462, in IBKRConnectionManager._with_retry(self, call, operation)
#     461 async def _with_retry(self, call: Any, *, operation: str) -> Any:
# --> 462     return await self.with_retry(call, operation=operation)
#
# File ~/PycharmProjects/IBPython/src/feeds/ibkr_connection.py:458, in IBKRConnectionManager.with_retry(self, call, operation)
#     456 metrics.ibkr_request_duration.observe(elapsed, {"operation": operation, "status": "error"})
#     457 metrics.ibkr_request_errors.inc({"operation": operation, "error_type": error_type})
# --> 458 raise RuntimeError(f"IBKR operation failed after retries: {operation}") from last_error
#
# RuntimeError: IBKR operation failed after retries: connect
